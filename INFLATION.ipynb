# %%
import pandas as pd

# %%
Dataset=pd.read_csv("newData.csv")

# %%
Dataset
# Out:
#                     Country_Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                             Indicator Name  Indicator Code      1960  \
# 0    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 1    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 2    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# 3    Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG       NaN
# ...

# %%
Dataset.head()
# Out:
#                   Country_Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                           Indicator Name  Indicator Code  1960  1961  1962  \
# 0  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 1  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 2  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 3  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
# 4  Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG   NaN   NaN   NaN
#
#    1963  1964  1965  ...       2012      2013      2014      2015       2016  \
# 0   NaN   NaN   NaN  ...   0.627472 -2.372065  0.421441  0.474764  -0.931196
# 1   NaN   NaN   NaN  ...   9.158707  5.750981  5.370290  5.250171   6.571396
# ...

# %%
Dataset['Country_Name']
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: Country_Name, Length: 266, dtype: object

# %%
Dataset.shape
# Out:
# (266, 66)

# %%
Dataset['Country_Name'][83]
# Out:
# 'Ghana'

# %%
Dataset.Country_Name='Ghana'

# %%
Dataset.Country_Name =='Ghana'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 261    True
# 262    True
# 263    True
# 264    True
# 265    True
# Name: Country_Name, Length: 266, dtype: bool

# %%
Dataset.loc[Dataset.Country_Name =='Ghana']
# Out:
#     Country_Name Country Code                         Indicator Name  \
# 0          Ghana          ABW  Inflation, consumer prices (annual %)
# 1          Ghana          AFE  Inflation, consumer prices (annual %)
# 2          Ghana          AFG  Inflation, consumer prices (annual %)
# 3          Ghana          AFW  Inflation, consumer prices (annual %)
# 4          Ghana          AGO  Inflation, consumer prices (annual %)
# ..           ...          ...                                    ...
# 261        Ghana          XKX  Inflation, consumer prices (annual %)
# 262        Ghana          YEM  Inflation, consumer prices (annual %)
# 263        Ghana          ZAF  Inflation, consumer prices (annual %)
# 264        Ghana          ZMB  Inflation, consumer prices (annual %)
# 265        Ghana          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961      1962     1963      1964  \
# ...

# %%
Ghana_Column=Dataset.loc[Dataset.Country_Name=='Ghana']

# %%
Ghana_Column
# Out:
#     Country_Name Country Code                         Indicator Name  \
# 0          Ghana          ABW  Inflation, consumer prices (annual %)
# 1          Ghana          AFE  Inflation, consumer prices (annual %)
# 2          Ghana          AFG  Inflation, consumer prices (annual %)
# 3          Ghana          AFW  Inflation, consumer prices (annual %)
# 4          Ghana          AGO  Inflation, consumer prices (annual %)
# ..           ...          ...                                    ...
# 261        Ghana          XKX  Inflation, consumer prices (annual %)
# 262        Ghana          YEM  Inflation, consumer prices (annual %)
# 263        Ghana          ZAF  Inflation, consumer prices (annual %)
# 264        Ghana          ZMB  Inflation, consumer prices (annual %)
# 265        Ghana          ZWE  Inflation, consumer prices (annual %)
#
#      Indicator Code      1960      1961      1962     1963      1964  \
# ...

# %%
Ghana_Column.to_csv('Ghana_inflation_dataset.csv')
